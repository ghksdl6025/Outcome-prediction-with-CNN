# %%
import pandas as pd

# %%
df = pd.read_csv('../data/bpic2011prep.csv')
print(df.head)
# Out:
# <bound method NDFrame.head of         Case ID                                  Activity  \
# 0             0                   1e consult poliklinisch
# 1             0  ligdagen - alle spec.beh.kinderg.-reval.
# 2             0              190205 klasse 3b        a205
# 3             0  ligdagen - alle spec.beh.kinderg.-reval.
# 4             0              190205 klasse 3b        a205
# ...         ...                                       ...
# 150286     1142             aanname laboratoriumonderzoek
# 150287     1142             aanname laboratoriumonderzoek
# 150288     1142             aanname laboratoriumonderzoek
# 150289     1142                   kalium potentiometrisch
# 150290     1142                               ordertarief
#
#          Complete Timestamp (case) Age (case) Age:1 (case) Age:2 (case) Age:3  \
# 0       2005-01-03 08:00:00       33.0         None         None         None
# 1       2005-02-20 08:00:00       33.0         None         None         None
# ...
